# %% [markdown]
# # Netflix Dataset - EDA

# %% [markdown]
#  Netflix is one of the most popular media and video streaming platforms. They have over 8000 movies or tv shows available on their platform, as of mid-2021, they have over 200M Subscribers globally. In this project the dataset taken from Kaggle consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc.

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\divle\Desktop\Projects\Netflix\netflix_titles.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# number of rows and columns
data.shape
# Out:
# (8807, 12)

# %%
# total number of elements in the dataset
data.size
# Out:
# 105684

# %%
# show each column name
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# show datatypes of each column
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Task 1: Find duplicate and null values

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# To see the duplicates we can use:
# data[data.duplicated()].
# To drop duplicates we can use:
# data.drop-duplicates(inplace=True).

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Use heatmap to show null values 
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Task 2: Information regarding particular show

# %%
data[data['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
data[data['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Task 3: Answering certain questions

# %%
# In which year highest number of TV Shows & Movies were released?

# %%
# Convert to date-time format 
data['Date_N']=pd.to_datetime(data['date_added'],errors='coerce', format="%B %d, %Y")

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    1999
# 2020.0    1878
# 2018.0    1625
# 2021.0    1498
# 2017.0    1164
# 2016.0     418
# 2015.0      73
# 2014.0      23
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.title('Year-wise Releases')
# Out:
# Text(0.5, 1.0, 'Year-wise Releases')

# %%
# Total number of TV Shows & Movies

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data=data,x='type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Distribution of Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Types')

# %%
# Show movies released in year 2000

# %%
data['Year']=data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['type']=='Movie')&(data['Year']==2020)]
# Out:
#      show_id   type                                title  \
# 1470   s1471  Movie                     Alaska Is a Drag
# 1471   s1472  Movie                Best of Stand-Up 2020
# 1472   s1473  Movie                         Bobby Jasoos
# 1474   s1475  Movie                        Tarung Sarung
# 1475   s1476  Movie               Too Handsome to Handle
# ...      ...    ...                                  ...
# 8742   s8743  Movie                       Wild Wild West
# 8743   s8744  Movie                             Wildlife
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory
# 8764   s8765  Movie                           Wyatt Earp
# 8805   s8806  Movie                                 Zoom
#
#                        director  \
# 1470               Shaz Bennett
# 1471                        NaN
# 1472               Samar Shaikh
# 1474            Archie Hekagery
# 1475  Sabrina Rochelle Kalangie
# ...                         ...
# 8742           Barry Sonnenfeld
# ...

# %%
# Show TV Shows released in India

# %%
data[(data['type']== 'TV Show')& (data['country']=='India')] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
# Show top 10 directors, who gave highest number of Shows and Movies

# %%
data['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
# Show records where Category is Movie and Type is Comedies or country is UK

# %%
data[(data['type']=='Movie')&(data['listed_in']=='Comedies')| (data['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
# In how many movies Tom Cruise was a cast?

# %%
data[data['cast'].str.contains('Tom Cruise')]      #throws error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 data[data['cast'].str.contains('Tom Cruise')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     132         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %%
data_new=data.dropna()

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description     Date_N    Year
# 341   Through chance, history and divine interventio... 2021-08-01  2021.0
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021.0

# %%
# What are the different ratings defined by Netflix?

# %%
data.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
data.rating.nunique()
# Out:
# 17

# %%
# Which movies got TV-14 rating in Canada?

# %%
data[(data['type']=='Movie')&(data['rating']=='TV-14')&(data['country']=='Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
# How many Shows got R rating after 2018

# %%
data[(data['type']=='TV Show')&(data['rating']=='R')&(data['Year']>2018)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 3893  April 25, 2019          2015      R  1 Season  TV Shows
#
#                                             description     Date_N    Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
# Max duration

# %%
data.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %%
data[['Minutes','Unit']]=data['duration'].str.split(' ',expand=True)

# %%
data['Minutes'] = pd.to_numeric(data['Minutes'], errors='coerce')

# %%
data['Minutes'].max()
# Out:
# 312.0

# %%
data['Minutes'].min()
# Out:
# 1.0

# %%
# Which country has highest number of shows?

# %%
data_show=data[data['type']=='TV Show']

# %%
data_show.country.value_counts()
# Out:
# country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %%
data_show.country.value_counts().head(1)
# Out:
# country
# United States    760
# Name: count, dtype: int64

# %%
# Sort dataset by Year

# %%
data.sort_values(by='Year')
# Out:
#      show_id     type                        title              director  \
# 5957   s5958    Movie         To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show              Dinner for Five                   NaN
# 5955   s5956    Movie                     Splatter             Joe Dante
# 5956   s5957    Movie      Just Another Love Story          Ole Bornedal
# 7370   s7371    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                          ...                   ...
# 8539   s8540  TV Show                   The Tudors                   NaN
# 8557   s8558  TV Show                The West Wing                   NaN
# 8684   s8685  TV Show                      Vroomiz                   NaN
# 8712   s8713  TV Show   Weird Wonders of the World                   NaN
# 8755   s8756  TV Show            Women Behind Bars                   NaN
#
#                                                    cast  \
# ...

# %%
data.sort_values(by='Year',ascending=False).head(10)
# Out:
#      show_id     type                               title         director  \
# 0         s1    Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997    Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006    Movie  Keymon and Nani in Space Adventure              NaN
# 1004   s1005  TV Show                  Izzy's Koala World              NaN
# 1003   s1004  TV Show                                Zero              NaN
# 1002   s1003    Movie                        Tell Me When   Gerardo Gatica
# 1001   s1002    Movie                            Oloibiri    Curtis Graham
# 1000   s1001    Movie                            Wild Dog  Ahishor Solomon
# 999    s1000    Movie                            Stowaway        Joe Penna
# 998     s999    Movie                Searching For Sheela              NaN
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %%
# Find instances where category is movie and type is dramas or category is TV Show and type is Kids TV

# %%
filtered_data = data[((data['type'] == 'Movie') & (data['listed_in'] == 'Dramas')) | ((data['type'] == 'TV Show') & (data['listed_in'] == "Kids' TV"))]

# %%
filtered_data
# Out:
#      show_id     type                    title          director  \
# 34       s35  TV Show  Tayo and Little Wizards               NaN
# 39       s40  TV Show             Chhota Bheem               NaN
# 65       s66  TV Show             Numberblocks               NaN
# 89       s90  TV Show              Mighty Raju               NaN
# 100     s101  TV Show  Tobot Galaxy Detectives               NaN
# ...      ...      ...                      ...               ...
# 8691   s8692    Movie                Wakefield     Robin Swicord
# 8696   s8697    Movie                War Horse  Steven Spielberg
# 8783   s8784  TV Show                     Yoko               NaN
# 8785   s8786  TV Show                      YOM               NaN
# 8797   s8798  TV Show                Zak Storm               NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# ...
